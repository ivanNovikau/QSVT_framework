# %%
from IPython.core.display import display, HTML
import scipy.constants as sc
from scipy.optimize import fsolve
from ipywidgets import interact, widgets
# %matplotlib notebook

import numpy as np
import cmath
import matplotlib.pyplot as plt
import scipy.constants as sc
plt.rcParams.update({
    "text.usetex": True,
    'text.latex.preamble': r"\usepackage{amsmath} \boldmath"
})
import os

print(os.getpid())
# %cd ../
# Out:
# 13751
# /media/work/docs/codes/c++/QSVT_framework/simulations

# %%
import pylib.measurement as mse
import pylib.mix as mix
import waves_dielectrics.stationary_sim as sim

# %%
alpha = 0.1
n = 10
sep_angles = [alpha/2.**xx for xx in range(n)]
print(sep_angles)

print(np.sum(sep_angles))
print(2*alpha * (1 - 0.5**n))

res_angles = np.zeros(2**n)
for ii in range(2**n):
    bit_array = mix.find_bit_array_of_int(ii, n)
#     print(bit_array)
    res_angles[ii] = np.sum([sep_angles[iqq] * bit_array[iqq] for iqq in range(n)])
print(res_angles)
# Out:
# [0.1, 0.05, 0.025, 0.0125, 0.00625, 0.003125, 0.0015625, 0.00078125, 0.000390625, 0.0001953125]
# 0.19980468750000002
# 0.19980468750000002
# [0.000e+00 1.953e-04 3.906e-04 ... 1.994e-01 1.996e-01 1.998e-01]

# %%
# option 1
res_x = np.sin(res_angles)

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(res_angles, res_x, color='b', marker = "o", linewidth = 2, linestyle='-', label = "option 1")
plt.xlabel('angles')
plt.ylabel("res. x-coordinate")
ax.legend()
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
